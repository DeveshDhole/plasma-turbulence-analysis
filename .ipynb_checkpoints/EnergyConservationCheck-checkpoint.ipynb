# %%
import h5py
import matplotlib.pyplot as plt

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import os

# --- File paths (choose one run) ---
Base_dir = "/home/UNN/w24021992/NAS/simulations_beta_scan/beta_p_16/beta_e_1"

File_Etot = f"{Base_dir}/EnTot_ApJ_.h5"
File_Time = f"{Base_dir}/Time_ApJ_.h5"

# --- Helper function ---
def load_dataset(fp):
    with h5py.File(fp, "r") as f:
        key = list(f.keys())[0]
        return f[key][:]

# --- Load data ---
E = load_dataset(File_Etot)
t = load_dataset(File_Time)

# --- Normalize ---
E_norm = E / E[0]

# --- Make plots directory if needed ---
plot_dir = f"{Base_dir}/plots"
os.makedirs(plot_dir, exist_ok=True)

# --- Plot ---
plt.figure(figsize=(8, 5))
plt.xlim(0, 300)
plt.ylim(0.98, 1.02)

plt.plot(t, E_norm)
plt.xlabel("Time")
plt.ylabel(r"$E / E_0$")
plt.title("Normalized Total Energy vs Time")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(f"{plot_dir}/EnergyPlot.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 19
#      16         return f[key][:]
#      18 # --- Load data ---
# ---> 19 E = load_dataset(File_Etot)
#      20 t = load_dataset(File_Time)
#      22 # --- Normalize ---
#
# Cell In[1], line 14, in load_dataset(fp)
#      13 def load_dataset(fp):
# ---> 14     with h5py.File(fp, "r") as f:
#      15         key = list(f.keys())[0]
#      16         return f[key][:]
#
# File ~/miniconda3/envs/camelia/lib/python3.11/site-packages/h5py/_hl/files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
# ...

# %%
print((E_norm[-1]-1)*100)
# Out:
# -0.03542304
