# %%
#All the imports
import h5py
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from scipy.stats import norm
from scipy.stats import kurtosis
from scipy.ndimage import maximum_filter, label
import multiprocessing as mp
import os

# %%
#Function Definitions
def partial_x_2d(f,dx):
    """Compute ∂f/∂x using 2nd-order central differences with periodic BCs."""
    Nx, Ny = f.shape
    df_dx = np.zeros_like(f)
    
    # Central difference in x-direction (axis=0)
    df_dx[1:Nx-1, :] = (f[2:Nx, :] - f[0:Nx-2, :]) / (2 * dx)
    
    # Periodic boundaries (x-direction)
    df_dx[0, :] = (f[1, :] - f[-1, :]) / (2 * dx)
    df_dx[-1, :] = (f[0, :] - f[-2, :]) / (2 * dx)
    
    return df_dx

def partial_y_2d(f,dy):
    """Compute ∂f/∂y using 2nd-order central differences with periodic BCs."""
    Nx, Ny = f.shape
    df_dy = np.zeros_like(f)
    
    # Central difference in y-direction (axis=1)
    df_dy[:, 1:Ny-1] = (f[:, 2:Ny] - f[:, 0:Ny-2]) / (2 * dy)
    
    # Periodic boundaries (y-direction)
    df_dy[:, 0] = (f[:, 1] - f[:, -1]) / (2 * dy)
    df_dy[:, -1] = (f[:, 0] - f[:, -2]) / (2 * dy)
    
    return df_dy

def partial_x_fft(f, dx):
    """
    Calculate ∂f/∂x using FFT on a 2D grid.

    Parameters:
        f (2D np.array): Function values on a 2D grid (shape: Nx × Ny).
        dx (float): Grid spacing in the x-direction.

    Returns:
        df_dx (2D np.array): Partial derivative ∂f/∂x.
    """
    nx, ny = f.shape
    kx = np.fft.fftfreq(nx, d=dx) * 2 * np.pi  # Wavenumbers in x
    kx = kx[:, np.newaxis]                     # Make it 2D for broadcasting

    f_hat = np.fft.fft2(f)
    df_dx_hat = 1j * kx * f_hat
    df_dx = np.fft.ifft2(df_dx_hat).real

    return np.array(df_dx)

def partial_y_fft(f, dy):
    """
    Calculate ∂f/∂y using FFT on a 2D grid.

    Parameters:
        f (2D np.array): Function values on a 2D grid (shape: Nx × Ny).
        dy (float): Grid spacing in the y-direction.

    Returns:
        df_dy (2D np.array): Partial derivative ∂f/∂y.
    """
    nx, ny = f.shape
    ky = np.fft.fftfreq(ny, d=dy) * 2 * np.pi  # Wavenumbers in y
    ky = ky[np.newaxis, :]                     # Make it 2D for broadcasting

    f_hat = np.fft.fft2(f)
    df_dy_hat = 1j * ky * f_hat
    df_dy = np.fft.ifft2(df_dy_hat).real

    return df_dy

def index_of_just_smaller(arr, value):
    arr = np.asarray(arr)
    mask = arr < value
    if not np.any(mask):
        return None  # No smaller value exists
    return np.argmax(np.where(mask, arr, -np.inf))

# %%
# List of simulation directories
sim_dirs = [
    '/DATA/DEVESH/ExtremeBetaSimulations/16'
]

dx = 0.0625
dy = 0.0625

# %%
def process_sim_dir(sim_dir):
    B_rms = []
    for i in range(0, 300):
        print(f"{sim_dir}: i = {i}", flush=True)

        File_Bx = f'{sim_dir}/Bx_ApJ_t{i}.h5'
        File_By = f'{sim_dir}/By_ApJ_t{i}.h5'

        with h5py.File(File_Bx, 'r') as fBx, h5py.File(File_By, 'r') as fBy:
            data_Bx = fBx['DS1'][:].T
            data_By = fBy['DS1'][:].T

        data_Bp = np.sqrt(data_Bx**2 + data_By**2)
        Bp_rms = np.sqrt(np.mean(data_Bp**2))
        B_rms.append(Bp_rms)

    return sim_dir, B_rms


if __name__ == "__main__":
    with mp.Pool(processes=8) as pool:   # adjust to number of CPU cores
        results = pool.map(process_sim_dir, sim_dirs)

    all_B_rms = {sim_dir: B_rms for sim_dir, B_rms in results}
# Out:
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 0
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 1
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 2
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 3
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 4
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 5
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 6
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 7
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 8
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 9
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 10
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 11
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 12
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 13
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 14
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 15
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 16
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 17
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 18
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 19
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 20
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 21
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 22
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 23
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 24
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 25
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 26
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 27
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 28
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 29
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 30
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 31
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 32
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 33
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 34
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 35
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 36
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 37
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 38
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 39
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 40
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 41
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 42
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 43
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 44
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 45
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 46
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 47
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 48
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 49
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 50
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 51
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 52
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 53
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 54
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 55
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 56
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 57
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 58
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 59
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 60
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 61
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 62
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 63
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 64
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 65
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 66
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 67
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 68
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 69
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 70
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 71
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 72
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 73
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 74
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 75
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 76
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 77
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 78
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 79
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 80
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 81
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 82
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 83
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 84
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 85
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 86
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 87
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 88
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 89
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 90
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 91
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 92
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 93
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 94
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 95
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 96
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 97
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 98
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 99
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 100
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 101
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 102
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 103
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 104
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 105
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 106
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 107
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 108
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 109
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 110
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 111
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 112
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 113
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 114
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 115
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 116
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 117
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 118
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 119
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 120
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 121
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 122
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 123
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 124
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 125
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 126
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 127
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 128
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 129
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 130
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 131
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 132
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 133
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 134
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 135
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 136
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 137
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 138
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 139
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 140
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 141
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 142
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 143
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 144
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 145
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 146
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 147
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 148
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 149
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 150
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 151
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 152
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 153
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 154
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 155
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 156
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 157
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 158
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 159
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 160
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 161
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 162
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 163
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 164
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 165
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 166
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 167
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 168
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 169
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 170
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 171
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 172
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 173
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 174
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 175
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 176
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 177
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 178
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 179
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 180
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 181
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 182
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 183
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 184
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 185
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 186
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 187
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 188
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 189
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 190
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 191
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 192
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 193
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 194
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 195
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 196
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 197
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 198
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 199
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 200
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 201
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 202
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 203
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 204
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 205
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 206
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 207
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 208
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 209
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 210
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 211
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 212
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 213
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 214
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 215
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 216
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 217
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 218
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 219
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 220
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 221
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 222
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 223
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 224
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 225
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 226
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 227
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 228
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 229
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 230
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 231
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 232
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 233
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 234
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 235
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 236
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 237
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 238
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 239
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 240
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 241
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 242
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 243
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 244
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 245
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 246
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 247
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 248
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 249
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 250
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 251
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 252
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 253
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 254
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 255
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 256
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 257
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 258
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 259
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 260
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 261
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 262
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 263
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 264
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 265
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 266
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 267
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 268
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 269
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 270
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 271
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 272
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 273
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 274
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 275
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 276
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 277
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 278
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 279
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 280
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 281
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 282
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 283
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 284
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 285
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 286
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 287
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 288
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 289
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 290
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 291
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 292
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 293
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 294
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 295
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 296
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 297
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 298
# /DATA/DEVESH/ExtremeBetaSimulations/16: i = 299

# %%
timesteps = np.arange(0, 300)

plt.figure(figsize=(10, 6))

for sim_dir, B_rms in all_B_rms.items():
    # Plot J_rms vs time for each simulation
    plt.plot(timesteps, B_rms, label=sim_dir.split('/')[-1])  # using last folder name as label

plt.xlabel('Timestep')
plt.ylabel(r'$B_{rms}$')
plt.title('B_rms vs Time for Different Simulations')
plt.legend()
# plt.grid(True)
plt.tight_layout()
plt.savefig("Brms.png", dpi=300)
plt.show()

# %%
idx_max = np.argmax(B_rms)
print(idx_max)
# Out:
# 31
